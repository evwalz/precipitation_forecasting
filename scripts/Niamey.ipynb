# %%
import pickle
import numpy as np
from helpers import *
from pit_corp import compute_rel, compute_pit

# %%
data_dir = '/Volumes/My Passport for Mac/cnn/data_update/with_precip/precip_data'
#data_dir = "../precip_data"
season = 'JAS'

# %% [markdown]
# # CORP

# %%
from corp_functions import reldiag

# %%
# mpc, logit, logit_base, cnn, hres, ensemble, hybrid, ensemble_pp

# %%
model = 'mpc' 
rel_object = compute_rel(model, season, data_dir)

# %%
reldiag.corp_plot(rel_object, True)

# %% [markdown]
# # PIT

# %%
# mpc, dim, dim_base, hres, cnn, hybrid, ensemble, emos

# %%
model = 'ensemble'
pit_vals = compute_pit(model, season, data_dir)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6,5))
x = ax.hist(pit_vals, bins = 20, color = "darkgrey", edgecolor='black', density = True, linewidth = 1.2)
x = ax.axhline(1, color = 'black', linestyle = '--')
x = ax.set_xticks([0,0.25,  0.5, 0.75, 1])
x = ax.set_ylabel('Density')

# %%
X = np.loadtxt('/Volumes/My Passport for Mac/precip/corp_pit/pit_niamey/pit_emos_niamey.txt')

# %%
plt.hist(X, bins = 20)
# Out:
# (array([17., 17., 27., 23., 27., 28., 20., 28., 36., 59., 76., 63., 67.,
#         63., 39., 47., 33., 42., 48., 68.]),
#  array([8.41489897e-04, 5.07812635e-02, 1.00721037e-01, 1.50660811e-01,
#         2.00600584e-01, 2.50540358e-01, 3.00480132e-01, 3.50419905e-01,
#         4.00359679e-01, 4.50299452e-01, 5.00239226e-01, 5.50179000e-01,
#         6.00118773e-01, 6.50058547e-01, 6.99998320e-01, 7.49938094e-01,
#         7.99877868e-01, 8.49817641e-01, 8.99757415e-01, 9.49697188e-01,
#         9.99636962e-01]),
#  <BarContainer object of 20 artists>)
